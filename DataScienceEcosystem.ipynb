# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.51.14 AM.png](attachment:9ae2fff3-1ace-45b4-8c26-92e5d6ebea14.png)
#
# __Output:__
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.50.25 AM.png](attachment:540bd1cc-8681-44ff-bbfc-497dd55e7dac.png)
#
# __Output:__
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.49.26 AM.png](attachment:79b5683d-d2d9-4997-a506-ee4d93d5d14d.png)
#
# __Output:__
#
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
# 4. Julia

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.51.36 AM.png](attachment:6da02c02-208d-4885-868b-fe6d51f6f0e4.png)
#
# __Output:__
#
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. ggplot
# 3. Matplotlib

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.52.47 AM.png](attachment:e1fd45dc-043c-49c9-93b2-705705df098c.png)
#
# __Output:__
#
# | Data Science Tools |
# | ------------------ |
# | Jupyter Notebooks |
# | RStudio |
# | Google Colab |

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.53.32 AM.png](attachment:a65493fd-11bf-4ff9-926d-8a9f347e701a.png)
#
# __Output:__
#
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Exercise 8 - Create a code cell to multiply and add numbers

# Mutiplying 3 * 4 and adding the product to 5
(3*4)+5
# Out:
# 17

# %%
# Exercise 9 - Create a code cell to convert minutes to hours

# Converting 200 minutes into hours (divide by 60)
# Also calculates the remainder to get the number of extra minutes
print(str(200 // 60), "hours and", str(200 % 60), "minutes")
# Out:
# 3 hours and 20 minutes

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.55.58 AM.png](attachment:19f72605-bbdc-4527-9876-99f5dc6156d6.png)
#
# __Output:__
#
# __Objectives:__
# - Listing popular languages in Data Science
# - Listing commonly used libraries in Data Science
# - Demonstrating how to calculate arithmetic expressions in Python

# %% [markdown]
# ![Screenshot 2024-02-17 at 10.56.30 AM.png](attachment:e49608a8-88e2-4ba9-971a-f58bc8f73aa7.png)
#
# __Output:__
#
# ## Author
# Hima Tummalapalli
